# %%
import pandas as pd
import sys
from importlib import reload
from scipy.io import savemat
sys.path.insert(0,'/Users/jakevogel/git/pycourse_vuMC/')
import pycourse_lesson3_4_scripts
sys.path.insert(0,'/Users/jakevogel/git/hack_projects/')
import kfold_learning as kfl
import numpy as np
import os

# %%
workdir = '/Users/jakevogel/Science/TADPOLE/'

full_df = pd.read_csv(os.path.join(workdir, 'inputed50_cleaned'))
ref_df = pd.read_csv(os.path.join(workdir, 'inputed50_ref.csv'))
d1d2 = pd.read_csv(os.path.join(workdir,'TADPOLE_D1_D2.csv'))

full_df.drop(full_df.columns[0], axis=1, inplace=True)

missing_ids = [x for x in ref_df.RID.unique() if any([not pd.notnull(y) for y in ref_df[ref_df.RID==x]['y_DX']])]
for i,sub in enumerate(missing_ids):
    jnk = ref_df[ref_df.RID==sub]['y_DX'].fillna(method='ffill')
    ref_df.loc[ref_df.RID==sub,'y_DX'] = jnk.values

full_df = full_df.loc[ref_df.dropna().index].reset_index(drop=True)
ref_df = ref_df.loc[ref_df.dropna().index].reset_index(drop=True)

code = {1: 0, 2:1, 3:2}
ref_df['y_DX'] = [code[x] for x in ref_df['y_DX']]

full_df['RID'] = ref_df['RID']
full_df['VISCODE'] = ref_df['VISCODE']
full_df['COLPROT'] = ref_df['COLPROT']
full_df['EXAMDATE'] = ref_df['EXAMDATE']
full_df['Month_bl'] = d1d2['Month_bl']

data = full_df

target = ref_df[['y_DX', 'y_ADAS13', 'y_Ventricles_adj_TIV']]
# target = target.dropna(axis=0)
# data = data.loc[target.index]
# data = data.dropna(axis=1)
# target = target.loc[data.index]
target['Month_bl'] = data['Month_bl']
target = target[['Month_bl', 'y_DX', 'y_ADAS13', 'y_Ventricles_adj_TIV']]

for col in target.columns[1:]:
    data[col] = target[col]
# Out:
# //anaconda/envs/py3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (471,473,474,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,569,570,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,599,601,606,607,608,609,610,611,612,613,614,615,616,617,618,619,620,621,624,625,626,627,628,629,630,631,632,633,634,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,661,663,664,665,666,667,668,669,670,671,672,673,674,675,676,677,678,679,680,681,682,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,716,717,718,719,720,721,
# ...

# %%
full_df[full_df.index[:373]]
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.069575 -0.874880  0.004105 -0.172768 -0.253396 -0.486480 -0.819258
# 1      1.073477 -0.874880  0.710920 -0.172768 -0.253396 -0.486480  0.705575
# 2      1.073477 -0.874880  0.710920 -0.172768 -0.253396 -0.486480  0.705575
# 3      1.073477 -0.874880  0.710920 -0.172768 -0.253396 -0.486480  0.705575
# 4      1.073477 -0.874880  0.710920 -0.172768 -0.253396 -0.486480  0.705575
# 5     -0.905643 -0.874880 -2.116339  4.591811 -0.253396 -0.486480 -0.819258
# 6     -0.905643 -0.874880 -2.116339  4.591811 -0.253396 -0.486480 -0.819258
# 7     -0.905643 -0.874880 -2.116339  4.591811 -0.253396 -0.486480 -0.819258
# 8     -0.905643 -0.874880 -2.116339  4.591811 -0.253396 -0.486480 -0.819258
# 9     -0.905643 -0.874880 -2.116339  4.591811 -0.253396 -0.486480 -0.819258
# 10    -0.016473 -0.874880  0.004105 -0.172768 -0.253396 -0.486480 -0.819258
# ...

# %%
jnk.columns
# Out:
# Index(['Unnamed: 0', 'AGE', 'PTGENDER', 'PTEDUCAT', 'PTETHCAT', 'PTRACCAT',
#        'PTMARRY', 'APOE4', 'CDRSB', 'MMSE',
#        ...
#        'ST97TS_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST98CV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST98SA_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST98TA_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST98TS_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST99CV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST99SA_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST99TA_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST99TS_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST9SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16'],
#       dtype='object', length=374)

# %%
full_df.columns
# Out:
# RangeIndex(start=0, stop=380, step=1)

# %%
output = kfl.kfold_feature_learning(data, data.loc[ref_df[ref_df.D2==2].index], 
                                    target.y_ADAS13, 
                                    target.loc[ref_df[ref_df.D2==2].index]['y_ADAS13'],
                                    folds=10, scale=False, weighted = True)
# Out:
# running model for fold 1 of 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-aa6fa9027a80> in <module>()
#       2                                     target.y_ADAS13,
#       3                                     target.loc[ref_df[ref_df.D2==2].index]['y_ADAS13'],
# ----> 4                                     folds=10, scale=False, weighted = True)
#
# /Users/jakevogel/git/hack_projects/kfold_learning.py in kfold_feature_learning(train, test, y, t_y, clf, problem, folds, scale, verbose, search, p_cutoff, regcols, regdf, keep_cols, out_dir, output, save_int, vote, weighted)
#     229             model = new_clf.fit(sig_mtx,y[sig_mtx.index])
#     230         else:
# --> 231             model = clf.fit(sig_mtx,y[sig_mtx.index])
#     232         if hasattr(model, 'coef_'):
#     233             try:
#
# ...

# %% [markdown]
# ## Prepare Spreadsheet

# %%
def encode(col, code_dict=None):
    '''col is a pandas Series or list as input. Code_dict is a dict such that keys are entries
    that exist in col, and values are new entries to replace the key, thus "encoding" the column.
    If code_dict = None, will automatically encode unique values with sequential integers.
    Returns pandas Series.'''
    
    col = pandas.Series(deepcopy(col))
    net = []
    if not code_dict:
        code_dict = {}
        for i,val in enumerate(col.unique()):
            if pandas.notnull(val):
                code_dict.update({val: i+1})
            else: 
                code_dict.update({val: 0})
    else:
        if type(code_dict) != dict:
            raise ValueError('code_dict must be a dictionary object')
        
    for i,val in enumerate(col):
        if val in code_dict.keys():
            col[i] = code_dict[val]
        else:
            net.append(val)
    if len(net) > 0:
        print('the following values were not assigned labels:')
        for miss in set(net):
            print(miss)
    
    return col, code_dict

# %%
# Note the na_values -- this is because the NaNs were set as a space and it was fuckin shit up
df = pandas.read_csv('/Users/jakevogel/Science/TADPOLE/TADPOLE_D1_D2.csv', na_values=' ')
# Out:
# //anaconda/envs/py3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1413,1656,1657,1659,1665,1666,1895,1902,1903,1904,1905) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (12741, 1907)

# %%
# Try to coerce object dtypes to numeric dtype. If this fails, encode to numerical values manually, save maps
maps = {}
for i,col in enumerate(df.columns[10:]):
    if df[col].dtype == 'object':
        try:
            df[col] = pandas.to_numeric(df[col])
        except:
            print('encoding %s, %s of %s'%(col,i,len(df.columns)))
            newcol, dmap = encode(df[col])
            df[col] = newcol
            maps.update({col: dmap})
# Out:
# encoding PTGENDER, 2 of 1907
# encoding PTETHCAT, 4 of 1907
# encoding PTRACCAT, 5 of 1907
# encoding PTMARRY, 6 of 1907
# encoding FLDSTRENG, 35 of 1907
# encoding FSVERSION, 36 of 1907
# encoding DX, 44 of 1907
# encoding EXAMDATE_bl, 45 of 1907
# encoding FLDSTRENG_bl, 55 of 1907
# encoding FSVERSION_bl, 56 of 1907
# encoding update_stamp, 86 of 1907
# encoding EXAMDATE_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 87 of 1907
# encoding VERSION_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 88 of 1907
# encoding RUNDATE_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 93 of 1907
# encoding STATUS_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 94 of 1907
# encoding OVERALLQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 103 of 1907
# encoding TEMPQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 104 of 1907
# encoding FRONTQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 105 of 1907
# encoding PARQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 106 of 1907
# encoding INSULAQC_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16, 107 of 1907
# ...

# %%
# Yasser wanted me to save this to a matfile. It took like 30 minutes and was like 1.5GB :-{
ddict = {}
ddict.update({'data': df.values})
ddict.update({'columns': df.columns.tolist()})
newmat = savemat('/Users/jakevogel/Science/TADPOLE/encoded',ddict)

# %%
# Save encoded data to CSV
df.to_csv('/Users/jakevogel/Science/TADPOLE/encoded.csv')

# %%
# save maps to a file
fields = []
frames = []
for field, d in maps.items():
    fields.append(field)
    frames.append(pandas.DataFrame.from_dict(d, orient='index'))

map_df = pandas.concat(frames, keys=fields)
map_df.to_csv('/Users/jakevogel/Science/TADPOLE/data_map')

# %%
dat = pandas.read_csv('/Users/jakevogel/Science/TADPOLE/imputed_d1_d2.csv')

# %%
map_df = pandas.read_csv('/Users/jakevogel/Science/TADPOLE/data_map')

# %%
map_df.loc['DX']
# Out:
#                  0
# NaN              0
# Dementia to MCI  7
# MCI              3
# MCI to Dementia  5
# NL to MCI        4
# Dementia         2
# MCI to NL        6
# NL               1
# NL to Dementia   9

# %%
newcode = {0: np.nan, 1:1, 2:3, 3:2, 4:2, 5:3, 6:1, 7:2, 9:3}
dat.DX = [newcode[x] for x in dat.DX]

# %%
test = dat[dat.D2==1]
train = dat[dat.D2 ==0]

# %%
ADAS_test = test.ADAS13
ADAS_train = train.ADAS13
test.drop('ADAS13',axis=1,inplace=True)
train.drop('ADAS13',axis=1,inplace=True)

vent_test = test.Ventricles / test.ICV
vent_train = train.Ventricles / train.ICV
test.drop('Ventricles',axis=1,inplace=True)
train.drop('Ventricles',axis=1,inplace=True)

DX_test = test.DX
DX_train = train.DX
test.drop('DX',axis=1,inplace=True)
train.drop('DX',axis=1,inplace=True)
# Out:
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
train[train.columns[:-20]]
# Out:
#        Unnamed: 0      AV45      CDRSB     ADAS11       MMSE  RAVLT_immediate  \
# 1               1  1.408452   4.500000  22.000000  20.000000        22.000000
# 2               2  1.410108   6.000000  19.000000  24.000000        19.000000
# 3               3  1.408466   3.500000  24.000000  17.000000        31.000000
# 4               4  1.409801   8.000000  25.670000  19.000000        23.000000
# 5               5  1.258025   1.000000  14.330000  27.000000        37.000000
# 6               6  1.275602   0.500000  17.330000  28.000000        33.000000
# 7               7  1.258008   1.000000  15.000000  26.000000        37.000000
# 8               8  1.275621   1.000000  20.330000  27.000000        44.000000
# 9               9  1.275637   1.000000  18.000000  25.000000        44.000000
# 10             10  1.401734   0.000000   8.670000  29.000000        37.000000
# 11             11  1.408522   0.000000  11.000000  29.000000        36.000000
# ...

# %%
from sklearn import model_selection
params1 = {'loss': ['hinge','log', 'modified_huber', 'squared_hinge', 'perceptron'],
          'penalty': ['none', 'l2', 'l1'],
          'alpha': [0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.1]} 
params2 = {'loss': ['hinge','log', 'modified_huber', 'squared_hinge'],
          'penalty': ['elasticnet'],
          'alpha': [0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.1],
          'l1_ratio': [0.05,0.1,0.15,0.2,0.3,0.5]}

# %%
selector = model_selection.GridSearchCV(linear_model.SGDClassifier(random_state=123),
                                        [params1,params2],cv=10)

# %%
output = kfl.kfold_feature_learning(train.loc[DX_train.dropna().index][train.columns[:-20]], 
                                    test.loc[DX_test.dropna().index][test.columns[:-20]], 
                                    DX_train.dropna(), DX_test.dropna(), clf = selector,
                           folds=3, scale=False, problem = 'classification', search = True, 
                                    weighted=True, vote='hard')
# Out:
# running model for fold 1 of 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-137-acee91afee36> in <module>()
#       3                                     DX_train.dropna(), DX_test.dropna(), clf = selector,
#       4                            folds=3, scale=False, problem = 'classification', search = True,
# ----> 5                                     weighted=True, vote='hard')
#
# /Users/jakevogel/git/hack_projects/kfold_learning.py in kfold_feature_learning(train, test, y, t_y, clf, problem, folds, scale, verbose, search, p_cutoff, regcols, regdf, keep_cols, out_dir, output, save_int, vote, weighted)
#     225                 sig_mtx[col] = tmp_mtx.ix[:,col]
#     226         if search:
# --> 227             mod_sel = clf.fit(sig_mtx,y[sig_mtx.index])
#     228             new_clf = mod_sel.best_estimator_
# ...

# %%
output = kfl.kfold_feature_learning(train[train.columns[:-20]], test[test.columns[:-20]], ADAS_train, ADAS_test,
                           folds=10, scale=False, weighted = True)
# Out:
# running model for fold 1 of 10
# running model for fold 2 of 10
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# running model for fold 3 of 10
# //anaconda/envs/py3/lib/python3.5/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# running model for fold 4 of 10
# running model for fold 5 of 10
# ...

# %%
kfl.kfold_feature_learning?

# %%
jnk = train[train.columns[:-20]]

# %%
jnk[jnk.columns[[x for x in range(len(output[0])) if output[0][x]>0]]].columns
# Out:
# Index(['Unnamed: 0', 'WholeBrain', 'ICV_bl',
#        'LONIUID_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST108CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST10CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST110CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST116CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST17SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST31CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST37SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST51CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST56CV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'ST89SV_UCSFFSL_02_01_16_UCSFFSL51ALL_08_01_16',
#        'LONIUID_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'IMAGEUID_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST108CV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST110CV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
#        'ST128SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
# ...

# %%
5*1100*1100*8
# Out:
# 48400000

# %%
df = pandas.read_csv()
