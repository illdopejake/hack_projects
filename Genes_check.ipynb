# %%
import pandas
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stat

# %%
df = pandas.read_table('/Users/jakevogel/Science/PRSice_v1.25/run_20170908_firsttry/PRSice_SCORES_AT_ALL_THRESHOLDS.txt',delim_whitespace=True)
df1 = pandas.read_table('/Users/jakevogel/Science/PRSice_v1.25/PRSice_SCORES_AT_ALL_THRESHOLDS.txt',delim_whitespace=True)
df.head()
# Out:
#       IID   pT_0.01   pT_0.02   pT_0.03   pT_0.04   pT_0.05   pT_0.06  \
# 0    1274  0.000445  0.000833  0.000837  0.000694  0.000776  0.000795
# 1   22453  0.000319  0.000518  0.000420  0.000247  0.000233  0.000195
# 2   75717 -0.001488 -0.000940 -0.000899 -0.000998 -0.000907 -0.000923
# 3  106871 -0.000833 -0.000358 -0.000445 -0.000416 -0.000482 -0.000571
# 4  112288  0.001251  0.001623  0.001395  0.001377  0.001344  0.001232
#
#     pT_0.07   pT_0.08   pT_0.09    ...      pT_0.41   pT_0.42   pT_0.43  \
# 0  0.000743  0.000714  0.000713    ...     0.000575  0.000575  0.000575
# 1  0.000163  0.000136  0.000136    ...     0.000151  0.000151  0.000151
# 2 -0.000945 -0.000943 -0.000940    ...    -0.001091 -0.001091 -0.001091
# 3 -0.000594 -0.000646 -0.000645    ...    -0.000689 -0.000689 -0.000689
# 4  0.001177  0.001174  0.001172    ...     0.001100  0.001100  0.001100
#
#     pT_0.44   pT_0.45   pT_0.46   pT_0.47   pT_0.48   pT_0.49    pT_0.5
# ...

# %%
df1.head()
# Out:
#       IID     pT_0   pT_0.01   pT_0.02   pT_0.03   pT_0.04   pT_0.05  \
# 0    1274  0.52075  0.001048  0.000641  0.000783  0.000764  0.000728
# 1   22453  0.00000  0.000904  0.000497  0.000422  0.000463  0.000445
# 2   75717  0.00000  0.000260  0.000385  0.000557  0.000560  0.000584
# 3  106871  0.52075  0.000753  0.000499  0.000517  0.000512  0.000523
# 4  112288  0.00000  0.000806  0.000591  0.000596  0.000488  0.000485
#
#     pT_0.06   pT_0.07   pT_0.08    ...      pT_0.41   pT_0.42   pT_0.43  \
# 0  0.000694  0.000670  0.000622    ...     0.000291  0.000286  0.000287
# 1  0.000411  0.000396  0.000403    ...     0.000199  0.000199  0.000201
# 2  0.000539  0.000479  0.000451    ...     0.000233  0.000228  0.000233
# 3  0.000499  0.000510  0.000468    ...     0.000248  0.000248  0.000249
# 4  0.000446  0.000367  0.000368    ...     0.000239  0.000235  0.000237
#
#     pT_0.44   pT_0.45   pT_0.46   pT_0.47   pT_0.48   pT_0.49    pT_0.5
# ...

# %%
plt.close()
sns.regplot(df['pT_0.01'],df1['pT_0.01'])
plt.show()

# %%
plt.close
sns.distplot(df['pT_0.01'])
plt.show()

# %%
plt.close()
sns.jointplot('pT_0.01','pT_0.5',data=df)
plt.show()
